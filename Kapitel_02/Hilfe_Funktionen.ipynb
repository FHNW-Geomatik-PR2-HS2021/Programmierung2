# %%
import numpy as np

# %%
x = np.linspace(-10, 10)
y = 0.5

X,Y = np.meshgrid(x, y)

# %%
X.shape, Y.shape
# Out:
# ((1, 50), (1, 50))

# %% [markdown]
# ## `help()`, `func?` und `func??`

# %%
# was macht meshgrid überhaupt?

help(np.meshgrid)
# Out:
# Help on function meshgrid in module numpy:
#
# meshgrid(*xi, copy=True, sparse=False, indexing='xy')
#     Return coordinate matrices from coordinate vectors.
#
#     Make N-D coordinate arrays for vectorized evaluations of
#     N-D scalar/vector fields over N-D grids, given
#     one-dimensional coordinate arrays x1, x2,..., xn.
#
#     .. versionchanged:: 1.9
#        1-D and 0-D cases are allowed.
#
#     Parameters
#     ----------
#     x1, x2,..., xn : array_like
#         1-D arrays representing the coordinates of a grid.
#     indexing : {'xy', 'ij'}, optional
#         Cartesian ('xy', default) or matrix ('ij') indexing of output.
#         See Notes for more details.
#
#         .. versionadded:: 1.7.0
#     sparse : bool, optional
#         If True a sparse grid is returned in order to conserve memory.
#         Default is False.
#
#         .. versionadded:: 1.7.0
#     copy : bool, optional
#         If False, a view into the original arrays are returned in order to
# ...

# %%
# gas gleiche wie oben
np.meshgrid?
# Out:
# Signature: np.meshgrid(*xi, copy=True, sparse=False, indexing='xy')
# Docstring:
# Return coordinate matrices from coordinate vectors.
#
# Make N-D coordinate arrays for vectorized evaluations of
# N-D scalar/vector fields over N-D grids, given
# one-dimensional coordinate arrays x1, x2,..., xn.
#
# .. versionchanged:: 1.9
#    1-D and 0-D cases are allowed.
#
# Parameters
# ----------
# x1, x2,..., xn : array_like
#     1-D arrays representing the coordinates of a grid.
# indexing : {'xy', 'ij'}, optional
#     Cartesian ('xy', default) or matrix ('ij') indexing of output.
#     See Notes for more details.
#
#     .. versionadded:: 1.7.0
# sparse : bool, optional
#     If True a sparse grid is returned in order to conserve memory.
#     Default is False.
#
#     .. versionadded:: 1.7.0
# copy : bool, optional
#     If False, a view into the original arrays are returned in order to
#     conserve memory.  Default is True.  Please note that
# ...

# %%
# docstring + source code
np.meshgrid??
# Out:
# Signature: np.meshgrid(*xi, copy=True, sparse=False, indexing='xy')
# Source:
# @array_function_dispatch(_meshgrid_dispatcher)
# def meshgrid(*xi, copy=True, sparse=False, indexing='xy'):
#     """
#     Return coordinate matrices from coordinate vectors.
#
#     Make N-D coordinate arrays for vectorized evaluations of
#     N-D scalar/vector fields over N-D grids, given
#     one-dimensional coordinate arrays x1, x2,..., xn.
#
#     .. versionchanged:: 1.9
#        1-D and 0-D cases are allowed.
#
#     Parameters
#     ----------
#     x1, x2,..., xn : array_like
#         1-D arrays representing the coordinates of a grid.
#     indexing : {'xy', 'ij'}, optional
#         Cartesian ('xy', default) or matrix ('ij') indexing of output.
#         See Notes for more details.
#
#         .. versionadded:: 1.7.0
#     sparse : bool, optional
#         If True a sparse grid is returned in order to conserve memory.
#         Default is False.
#
#         .. versionadded:: 1.7.0
# ...

# %% [markdown]
# ### Was ist ein `docstring`?

# %%
def func(a, b, msg=""):
    """Gibt den shape von `a` und `b` mit einem optionalen Message `msg` aus.
    
    Dies ist eine recht nutzlose Funktion, die demonstriert, wie ein docstring
    geschrieben wird (dieser folgt der numpy-docstring-style Konvetion:
    https://numpydoc.readthedocs.io/en/latest/format.html)
    
    Parameters
    ----------
    a : array_like
        Beiebiges N-D Array mit beliebige Dimension
    b : array_like
        Beiebiges N-D Array mit beliebige Dimension 

    msg : str, optional
        Ein Message für die Ausgabe. Standardwert ist eine Leere Zeichenkette.
        
        
    Beispiel
    --------
    >>> a = np.zeros(shape=(5,5,5))
    >>> b = np.zeros(shape=(1,3,3,10))
    >>> func(a, b, msg="Ergebnis:")a = np.zeros()
    Ergebnis: (5, 5, 5) (1, 3, 3, 10)
    """
    
    # dies ist der eigenliche Code
    print(msg, a.shape, b.shape)

# %%
a = np.zeros(shape=(5,5,5))
b = np.zeros(shape=(1,3,3,10))

func(a, b, msg="Ergebnis:")
# Out:
# Ergebnis: (5, 5, 5) (1, 3, 3, 10)

# %%
func?
# Out:
# Signature: func(a, b, msg='')
# Docstring:
# Gibt den shape von `a` und `b` mit einem optionalen Message `msg` aus.
#
# Dies ist eine recht nutzlose Funktion, die demonstriert, wie ein docstring
# geschrieben wird (dieser folgt der numpy-docstring-style Konvetion:
# https://numpydoc.readthedocs.io/en/latest/format.html)
#
# Parameters
# ----------
# a : array_like
#     Beiebiges N-D Array mit beliebige Dimension
# b : array_like
#     Beiebiges N-D Array mit beliebige Dimension
#
# msg : str, optional
#     Ein Message für die Ausgabe. Standardwert ist eine Leere Zeichenkette.
#
#
# Beispiel
# --------
# >>> a = np.zeros(shape=(5,5,5))
# >>> b = np.zeros(shape=(1,3,3,10))
# >>> func(a, b, msg="Ergebnis:")a = np.zeros()
# Ergebnis: (5, 5, 5) (1, 3, 3, 10)
# File:      /var/folders/8_/89sz7q3961n_2p6drnympl1w0000gn/T/ipykernel_61565/3937799358.py
# Type:      function

# %%
func??
# Out:
# Signature: func(a, b, msg='')
# Docstring:
# Gibt den shape von `a` und `b` mit einem optionalen Message `msg` aus.
#
# Dies ist eine recht nutzlose Funktion, die demonstriert, wie ein docstring
# geschrieben wird (dieser folgt der numpy-docstring-style Konvetion:
# https://numpydoc.readthedocs.io/en/latest/format.html)
#
# Parameters
# ----------
# a : array_like
#     Beiebiges N-D Array mit beliebige Dimension
# b : array_like
#     Beiebiges N-D Array mit beliebige Dimension
#
# msg : str, optional
#     Ein Message für die Ausgabe. Standardwert ist eine Leere Zeichenkette.
#
#
# Beispiel
# --------
# >>> a = np.zeros(shape=(5,5,5))
# >>> b = np.zeros(shape=(1,3,3,10))
# >>> func(a, b, msg="Ergebnis:")a = np.zeros()
# Ergebnis: (5, 5, 5) (1, 3, 3, 10)
# Source:
# def func(a, b, msg=""):
#     """Gibt den shape von `a` und `b` mit einem optionalen Message `msg` aus.
#
#     Dies ist eine recht nutzlose Funktion, die demonstriert, wie ein docstring
# ...
